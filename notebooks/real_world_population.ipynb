# %% [markdown]
# # Real-world population synthesis
#
# This notebook walks through the full pipeline:
#
# 1. **Fetch** raw demographic data from a census source
# 2. **Clean** it — rename columns, drop missing values, normalise distributions
# 3. **Build** `ZoneSpec` objects from the cleaned data
# 4. **Synthesise** a population with `synthesize_population()`
#
# Steps 2 and 3 are stubs — fill them in once you have the actual data.

# %% [markdown]
# ## 1. Imports

# %%
from pathlib import Path

from aibm.data_prep import load_census_data

# %% [markdown]
# ## 2. Fetch / load demographic data
#
# Point `DATA_PATH` at your census CSV.  For CBS (Statistics Netherlands) you
# can download *Kerncijfers wijken en buurten* from
# [statline.cbs.nl](https://statline.cbs.nl) and save it to `data/`.
#
# Alternatively, fetch it programmatically via the CBS OData API — add that
# logic here once you know the table identifier.

# %%
# TODO: point this at your actual data file
DATA_PATH = Path("../data/census.csv")

raw = load_census_data(DATA_PATH)
print(f"Rows loaded: {len(raw)}")
raw.head()

# %% [markdown]
# ## 3. Explore the raw data
#
# Before cleaning, get a feel for the columns and any missing values.

# %%
print(raw.dtypes)
print("\nMissing values:")
print(raw.isna().sum())

# %% [markdown]
# ## 4. Clean the data
#
# `clean_census_data()` is a stub — implement it in `src/aibm/data_prep.py`
# once you know the column names in your data source.

# %%
# TODO: uncomment once clean_census_data() is implemented
# clean = clean_census_data(raw)
# print(f"Zones after cleaning: {len(clean)}")
# clean.head()

# %% [markdown]
# ## 5. Build ZoneSpec objects

# %%
# TODO: uncomment once clean_census_data() is implemented
# specs = build_zone_specs(clean)
# print(f"ZoneSpecs built: {len(specs)}")
# print(specs[0])

# %% [markdown]
# ## 6. Synthesise the population

# %%
# TODO: uncomment once specs are ready
# households = synthesize_population(specs, seed=42)
# all_agents = [a for hh in households for a in hh.members]
# print(f"Households: {len(households)}")
# print(f"Agents    : {len(all_agents)}")
